# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/LR-by-codebasics/homeprices.csv')

# %%
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
df.shape
# Out:
# (6, 4)

# %%
# checking for NaN values across the data
df.isnull().sum()
# Out:
# area        0
# bedrooms    1
# age         0
# price       0
# dtype: int64

# %%
# Col wise NaN values in %
df.isnull().mean()*100
# Out:
# area         0.000000
# bedrooms    16.666667
# age          0.000000
# price        0.000000
# dtype: float64

# %%
df['bedrooms'].mean()
# Out:
# np.float64(4.2)

# %%
df['age'].mean()
# Out:
# np.float64(16.5)

# %%
df['bedrooms'].median()
# Out:
# 4.0

# %%
import math

# %%
df['bedrooms'] = df['bedrooms'].fillna(math.floor(df['bedrooms'].median()))

# %%
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
df.columns
# Out:
# Index(['area', 'bedrooms', 'age', 'price'], dtype='object')

# %%
X,y = df[['area', 'bedrooms', 'age']], df['price']
print(X.shape)
print(y.shape)
# Out:
# (6, 3)
# (6,)

# %%
X.head(3)
# Out:
#    area  bedrooms  age
# 0  2600       3.0   20
# 1  3000       4.0   15
# 2  3200       4.0   18

# %%
y.head(3)
# Out:
# 0    550000
# 1    565000
# 2    610000
# Name: price, dtype: int64

# %% [markdown]
# Model - LR

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
# [w1, w2, w3]
lr.coef_
# Out:
# array([  112.06244194, 23388.88007794, -3231.71790863])

# %%
# w0
lr.intercept_
# Out:
# np.float64(221323.00186540396)

# %%
# y = w0 + w1*x1 + w2*x2 + w3*x3
# price = w0 + w1*area + w2*bedrooms + w3*age

# %% [markdown]
# ''' find out price of a home that has
# 1. 3000 sqr ft area, 3 bedrooms, 40 year old
# 2. 2500 sqr ft area, 4 bedrooms, 5 year old
# '''

# %% [markdown]
# 1. Home has
# 3000 sqr ft area, 3 bedrooms, 40 year old

# %%
lr.predict([[3000, 3, 40]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([498408.25158031])

# %%
112.06244194*3000 + 23388.88007794*3 + -3231.71790863*40 + 221323.00186540396
# Out:
# 498408.251574024

# %% [markdown]
# 2. Home has 2500 sqr ft area, 4 bedrooms, 5 year old

# %%
lr.predict([[2500, 4, 5]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([578876.03748933])

# %%
112.06244194*2500 + 23388.88007794*4 + -3231.71790863*5 + 221323.00186540396
# Out:
# 578876.0374840139
